# %% [markdown]
# # Exercise 02: Classifier Comparison
#
# In this exercise, you'll run several classifiers on the same data and compare their effectiveness.

# %% [markdown]
# ## Installing Modules

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U scikit-learn matplotlib seaborn pandas
# Out:
# Requirement already satisfied: pip in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: scikit-learn in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (1.4.1.post1)
# Requirement already satisfied: matplotlib in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: seaborn in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: pandas in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/luke/.pyenv/versions/3.10.13/envs/3_week/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Setup

# %% [markdown]
# Load the pre-canned wine dataset:

# %%
from sklearn import datasets
dataset = datasets.load_wine()

# %% [markdown]
# Split test data into training/testing sets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dataset['data'], dataset['target'], test_size=0.4, random_state=20
)

# %% [markdown]
# ## K Nearest Neighbors
#
# Spend a little time learning about K Nearest Neighbor (KNN) classifiers.
#
# Once you have a handle on how they work, run the code below and inspect the results.

# %%
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

clf = KNeighborsClassifier(3)
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("K Nearest Neighbors Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier KNeighborsClassifier(n_neighbors=3):
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87        21
#            1       0.81      0.62      0.70        34
#            2       0.38      0.47      0.42        17
#
#     accuracy                           0.68        72
#    macro avg       0.66      0.68      0.66        72
# weighted avg       0.70      0.68      0.68        72
#
#
# Confusion matrix:
# [[20  0  1]
#  [ 1 21 12]
#  [ 4  5  8]]

# %% [markdown]
# ## Support Vector Machines
#
# Spend a little time learning about support vector machine (SVM) classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a support vector machine classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn import metrics

clf = SVC()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("SVC Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier SVC():
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        21
#            1       0.77      0.68      0.72        34
#            2       0.43      0.59      0.50        17
#
#     accuracy                           0.72        72
#    macro avg       0.73      0.72      0.72        72
# weighted avg       0.76      0.72      0.73        72
#
#
# Confusion matrix:
# [[19  0  2]
#  [ 0 23 11]
#  [ 0  7 10]]

# %% [markdown]
# ## Decision Trees
#
# Spend a little time learning about decision tree classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a decision tree classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("Decision Tree Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        21
#            1       0.97      0.94      0.96        34
#            2       0.94      1.00      0.97        17
#
#     accuracy                           0.96        72
#    macro avg       0.96      0.96      0.96        72
# weighted avg       0.96      0.96      0.96        72
#
#
# Confusion matrix:
# [[20  1  0]
#  [ 1 32  1]
#  [ 0  0 17]]

# %% [markdown]
# ## Random Forest Classifiers
#
# Spend a little time learning about random forest classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a random forest classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("Random Forest Classifier Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        17
#
#     accuracy                           1.00        72
#    macro avg       1.00      1.00      1.00        72
# weighted avg       1.00      1.00      1.00        72
#
#
# Confusion matrix:
# [[21  0  0]
#  [ 0 34  0]
#  [ 0  0 17]]

# %% [markdown]
# ## Questions

# %% [markdown]
# Compare and contrast the performance of the classifiers. Which do you think is best, and which worst? Are there any patterns? Anything else interesting to report?

# %% [markdown]
# It seems like the Random Forest Classifier was the best, with the SVC Matrix being the worst. It seems that 0 was guessed correctly the most betweeen all of them.

# %% [markdown]
# Was there a pattern to the changes you needed to make?  What does that say about the design of the `scikit-learn` estimators and APIs?

# %% [markdown]
# All of the changes were basically the same- it seems that the estimators and APIs are relatively interchangeable. The one exception is that some of them, like the Forest classifier do not require an additional parameter.

# %% [markdown]
# ## Follow-up
#
# Go back to the train/test split step, and change the `random_state` value.  Rerun the classifiers and inspect the results.  Do this several times for several `random_state` values.  What do you observe?

# %% [markdown]
# When I increased the random_state values, the accuracy went up. For example, at 20, I saw 100% accuracy with the forest model.

# %% [markdown]
# What does this imply about the training process?

# %% [markdown]
# This implies that

# %% [markdown]
# What is `random_state` doing?

# %% [markdown]
# Random_state seems to change the ordering of the datasets.

# %% [markdown]
# What should you do to ensure your ML results are reproducible?

# %% [markdown]
# You should have things saved in seeds, so that you can give the same data over and over in the same way to see if you can get the same results or results within a certain margin.

# %% [markdown]
# **MAKE SURE YOU SAVE, COMMIT, AND PUSH YOUR NOTEBOOKS TO YOUR REPO!!**
